# %%
import os
from dotenv import load_dotenv, find_dotenv
from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings

_ = load_dotenv(find_dotenv())

AZURE_OPENAI_HEADERS = {
    "x-service-line": os.getenv("SERVICE_LINE"),
    "x-brand": os.getenv("BRAND"),
    "x-project": os.getenv("PROJECT"),
    "api-version": os.getenv("API_VERSION"),
    # "api-version": os.getenv("OPENAI_API_VERSION"),
    "Content-Type": "application/json",
    "Cache-Control": "no-cache",
}

OPENAI_GPT3_KEY = os.environ["GPT3.5_KEY"]
OPENAI_GPT4_KEY = os.environ["GPT4_KEY"]
OPENAI_GPT4_1_KEY = os.environ["GPT4_1_KEY"]


def llm_gpt4o1():
    """
    Initialize and return an AzureChatOpenAI instance for GPT-4o.
    """
    headers = AZURE_OPENAI_HEADERS
    # headers["Ocp-Apim-Subscription-Key"] = OPENAI_GPT4_1_KEY
    headers["Ocp-Apim-Subscription-Key"] = os.getenv("GPT4_1_KEY")
    return AzureChatOpenAI(
        deployment_name="gpt-4.1-nano",
        model_name="gpt-4.1-nano",
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_version=os.getenv("OPENAI_API_VERSION"),
        default_headers=headers,
        seed=42,
        temperature=0.0,
        cache=False,
    )

def llm_gpt4o():
    """
    Initialize and return an AzureChatOpenAI instance for GPT-4o.
    """
    headers = AZURE_OPENAI_HEADERS
    # headers["Ocp-Apim-Subscription-Key"] = OPENAI_GPT4_KEY
    headers["Ocp-Apim-Subscription-Key"] = os.getenv("GPT4_KEY")
    return AzureChatOpenAI(
        deployment_name="GPT4o128k",
        model_name="GPT4o128k",
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_version=os.getenv("OPENAI_API_VERSION"),
        default_headers=headers,
        seed=42,
        temperature=0.0,
        cache=False,
    )

def azure_embeddings():
    """
    Initialize Azure OpenAI Embeddings (TextEmbeddingAda2).
    Used for semantic similarity (curated example selection, etc.)
    """
    headers = AZURE_OPENAI_HEADERS
    headers["Ocp-Apim-Subscription-Key"] = os.getenv("GPT3.5_KEY")
    # headers["Ocp-Apim-Subscription-Key"] = OPENAI_GPT3_KEY
    return AzureOpenAIEmbeddings(
        model="TextEmbeddingAda2",
        api_key=os.getenv("GPT3.5_KEY"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_version=os.getenv("OPENAI_API_VERSION"),
        default_headers=headers,
    )




llm = llm_gpt4o1()

# %%
llm.invoke("what is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_490a4ad033', 'id': 'chatcmpl-DIvKFUVjzVQRZ2FLOpZtUKKnHC5bJ', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 
# ...

# %%
from cryptography.hazmat.primitives.serialization import pkcs12, Encoding, PrivateFormat, NoEncryption
from cryptography.hazmat.primitives import hashes

PFX_PATH = r"C:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\cert.pfx"
PFX_PASSWORD = "StrongPassword123!"

with open(PFX_PATH, "rb") as f:
    pfx_data = f.read()

private_key, cert, additional = pkcs12.load_key_and_certificates(
    pfx_data,
    PFX_PASSWORD.encode("utf-8")
)

private_key_pem = private_key.private_bytes(
    encoding=Encoding.PEM,
    format=PrivateFormat.PKCS8,
    encryption_algorithm=NoEncryption()
).decode("utf-8")

thumbprint = cert.fingerprint(hashes.SHA1()).hex().upper()

print("THUMBPRINT:", thumbprint)
print("PRIVATE KEY PEM starts with:", private_key_pem.splitlines()[0])

# Write key next to the PFX (same folder)
out_path = r"C:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\private_key.pem"
with open(out_path, "w", encoding="utf-8") as f:
    f.write(private_key_pem)

print("Saved:", out_path)
# Out:
# THUMBPRINT: 35A45A9A41E4BF245C4AF33E1B15E55586F5B046
# PRIVATE KEY PEM starts with: -----BEGIN PRIVATE KEY-----
# Saved: C:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\private_key.pem

# %%
import os
print("Exists:", os.path.exists(r"C:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\cert.pfx"))
print("CWD:", os.getcwd())
# Out:
# Exists: True
# CWD: c:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\Notebook

# %%
import base64, json

def decode_jwt(access_token):
    payload = access_token.split(".")[1]
    payload += "=" * (-len(payload) % 4)
    return json.loads(base64.urlsafe_b64decode(payload))

claims = decode_jwt(token["access_token"])
print("aud:", claims.get("aud"))
print("roles:", claims.get("roles"))
print("scp:", claims.get("scp"))
# Out:
# aud: https://graph.microsoft.com
# roles: None
# scp: None

# %%
import requests
from msal import ConfidentialClientApplication

CLIENT_ID = "ddeb730f-9e0c-4882-bd24-35f19971e144"

# ✅ Paste Directory (tenant) ID from the Overview page (GUID format)
TENANT_ID = "6e8992ec-76d5-4ea5-8eae-b0c5e558749a"

THUMBPRINT = "35A45A9A41E4BF245C4AF33E1B15E55586F5B046"
PRIVATE_KEY = open(r"C:\Users\cchara01\OneDrive - dentsu\Documents\Python\dentsu-lead-management-ai\private_key.pem",
                   "r", encoding="utf-8").read()

app = ConfidentialClientApplication(
    client_id=CLIENT_ID,
    authority=f"https://login.microsoftonline.com/{TENANT_ID}",
    client_credential={"thumbprint": THUMBPRINT, "private_key": PRIVATE_KEY}
)

token = app.acquire_token_for_client(scopes=["https://graph.microsoft.com/.default"])
if "access_token" not in token:
    raise Exception(token)

headers = {"Authorization": f"Bearer {token['access_token']}"}

r = requests.get(
    "https://graph.microsoft.com/v1.0/sites/globalappsportal.sharepoint.com:/sites/DLQLeadQualificationOps?$select=id,webUrl",
    headers=headers
)

print(r.status_code)
print(r.text)
# Out:
# 401
# {"error":{"code":"generalException","message":"General exception while processing","innerError":{"date":"2026-03-13T15:37:39","request-id":"673380d1-0854-4745-91c1-eba319905b2f","client-request-id":"673380d1-0854-4745-91c1-eba319905b2f"}}}

# %%
import json

import requests
from msal import ConfidentialClientApplication

client_id = "ddeb730f-9e0c-4882-bd24-35f19971e144"
cert_thumbprint = "C8154B7BE634E73190654A261BC4F0854255A4EA"
tenant_id = "35A45A9A41E4BF245C4AF33E1B15E55586F5B046"

authority = f"https://login.microsoftonline.com/{tenant_id}"
private_key = """-----BEGIN PRIVATE KEY-----

Blt9rWkvxcab0v2a++folaGo
-----END PRIVATE KEY-----
"""

cert = {
    "private_key": private_key,
    "thumbprint": cert_thumbprint,
}

msal_app = ConfidentialClientApplication(
    client_id=client_id,
    authority=authority,
    client_credential=cert,
)

# scopes_graph = ["https://graph.microsoft.com/.default"]
scopes_sharepoint_online = ["https://x1dgq.sharepoint.com/.default"]

results = msal_app.acquire_token_for_client(scopes_sharepoint_online)

if "access_token" in results:
    access_token = results.get("access_token")

headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/json;odata=verbose",
    "Content-Type": "application/json",
}

sharepoint_base_url = "https://globalappsportal.sharepoint.com/:l:/r/sites/DLQLeadQualificationOps/Lists/LeadManagementQueue?e=l4LcKi"

sharepoint_url = f"{sharepoint_base_url}/_api/web/sitegroups"

response = requests.get(url=sharepoint_url, headers=headers)

print(response.status_code)
print(json.dumps(response.json(), indent=4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\cchara01\OneDrive - dentsu\Documents\Python\.venv\Lib\site-packages\msal\authority.py:99, in Authority.__init__(self, authority_url, http_client, validate_authority, instance_discovery, oidc_authority_url)
#      98 try:
# ---> 99     openid_config = tenant_discovery(
#     100         tenant_discovery_endpoint,
#     101         self._http_client)
#     102 except ValueError:
#
# File c:\Users\cchara01\OneDrive - dentsu\Documents\Python\.venv\Lib\site-packages\msal\authority.py:297, in tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs)
#     294 if 400 <= resp.status_code < 500:
#     295     # Nonexist tenant would hit this path
#     296     # e.g. https://login.microsoftonline.com/nonexist_tenant/v2.0/.well-known/openid-configuration
# ...
